# %%
import cv2
import sys

# %%
def get_data(input_path):
    """Parse the data from annotation file

	Args:
		input_path: annotation file path

	Returns:
		all_data: list(filepath, width, height, list(bboxes))
		classes_count: dict{key:class_name, value:count_num}
			e.g. {'Car': 2383, 'Mobile phone': 1108, 'Person': 3745}
		class_mapping: dict{key:class_name, value: idx}
			e.g. {'Car': 0, 'Mobile phone': 1, 'Person': 2}
	"""
    found_bg = False
    all_imgs = {}

    classes_count = {}

    class_mapping = {}

    i = 1

    with open(input_path, 'r') as f:

        print('Parsing annotation files')

        for line in f:

            # Print process
            sys.stdout.write('\r' + 'idx=' + str(i))
            i += 1

            line_split = line.strip().split(',')

            # Make sure the info saved in annotation file matching the format (path_filename, x1, y1, x2, y2, class_name)
            # Note:
            #	One path_filename might has several classes (class_name)
            #	x1, y1, x2, y2 are the pixel value of the origial image, not the ratio value
            #	(x1, y1) top left coordinates; (x2, y2) bottom right coordinates
            #   x1,y1-------------------
            #	|						|
            #	|						|
            #	|						|
            #	|						|
            #	---------------------x2,y2

            (filename, class_name, x1, y1, x2, y2) = line_split

            if class_name not in classes_count:
                classes_count[class_name] = 1
            else:
                classes_count[class_name] += 1

            if class_name not in class_mapping:
                class_mapping[class_name] = len(class_mapping)

            if filename not in all_imgs:
                all_imgs[filename] = {}

                img = cv2.imread('Dataset/' + filename)
                (rows, cols) = img.shape[:2]
                all_imgs[filename]['filepath'] = filename
                all_imgs[filename]['width'] = cols
                all_imgs[filename]['height'] = rows
                all_imgs[filename]['bboxes'] = []

            all_imgs[filename]['bboxes'].append({
                                        'class_id': class_mapping[class_name],
                                        'x_center': (int(x1) + int(x2)) / 2.0 / cols,
                                        'y_center': (int(y1) + int(y2)) / 2.0 / rows,
                                        'width': (int(x2) - int(x1)) / cols,
                                        'height': (int(y2) - int(y1)) / rows})

        all_data = []
        for key in all_imgs:
            all_data.append(all_imgs[key])

        return all_data, classes_count, class_mapping

# %%
trainImages, classesCount, classMapping= get_data('data.csv')
# Out:
# Parsing annotation files
# idx=4888

# %%
import yaml

# %%
def splitData(dataset,trainSize:float=0.8):
    splitIndex = int(trainSize * len(dataset))
    train:list=[]
    test:list=[]
    for i, file in enumerate(dataset):
        if i < splitIndex:
            train.append(file)
        else:
            test.append(file)
    return train, test

# %%
def create_yolo_yaml(data_paths, class_mapping,class_count, output_path='data.yaml'):
    """ 
    Create a YOLO configuration YAML file.
    
    Args:
        data_paths: dict with keys 'train', 'val', 'test' (optional)
                    Each value should be a path to the images directory or .txt file
        class_mapping: dict{key:class_name, value: idx}
                    e.g. {'Car': 0, 'Mobile phone': 1, 'Person': 2}
        output_path: path to save the YAML file
    """
    # Sort class names by their index to maintain order
    sorted_classes = [class_name for class_name, idx in 
                     sorted(class_mapping.items(), key=lambda x: x[1])]
    
    # Build the YAML structure
    yaml_data = {
        'path': '.',  # Root directory path (relative to current working directory)
        'train': data_paths.get('train', ''),
        'test': data_paths.get('test', ''),
        'nc': class_count,  # Number of classes
        'names': sorted_classes  # Class names in order
    }
    
    # Write YAML file
    with open(output_path, 'w') as f:
        yaml.dump(yaml_data, f, default_flow_style=False, sort_keys=False)

    return yaml_data

# %%
dataCombined:dict={}
dataCombined['train'], dataCombined['test'] = splitData(trainImages)
datasetYAMLformal = create_yolo_yaml(dataCombined,classMapping,classesCount)
# Out:
# YAML configuration saved to: data.yaml
# Number of classes: 3
# Class names: ['WBC', 'RBC', 'Platelets']
# {'path': '.',
#  'train': [{'filepath': 'BloodImage_00000.jpg',
#    'width': 640,
#    'height': 480,
#    'bboxes': [{'class_id': 0,
#      'x_center': 0.58671875,
#      'y_center': 0.5760416666666667,
#      'width': 0.3609375,
#      'height': 0.41458333333333336},
#     {'class_id': 1,
#      'x_center': 0.2046875,
#      'y_center': 0.803125,
#      'width': 0.165625,
#      'height': 0.20625},
#     {'class_id': 1,
#      'x_center': 0.18125,
#      'y_center': 0.596875,
#      'width': 0.165625,
#      'height': 0.20625},
#     {'class_id': 1,
#      'x_center': 0.4171875,
#      'y_center': 0.8572916666666667,
#      'width': 0.165625,
#      'height': 0.20625},
#     {'class_id': 1,
#      'x_center': 0.71875,
#      'y_center': 0.8302083333333333,
#      'width': 0.14375,
#      'height': 0.19375},
#     {'class_id': 1,
#      'x_center': 0.93359375,
#      'y_center': 0.8447916666666667,
#      'width': 0.1328125,
#      'height': 0.20625},
#     {'class_id': 1,
#      'x_center': 0.809375,
#      'y_center': 0.9291666666666667,
#      'width': 0.153125,
#      'height': 0.14166666666666666},
#     {'class_id': 1,
#      'x_center': 0.06875,
#      'y_center': 0.8020833333333334,
#      'width': 0.134375,
#      'height': 0.21666666666666667},
#     {'class_id': 1,
#      'x_center': 0.07734375,
#      'y_center': 0.9229166666666667,
#      'width': 0.1421875,
#      'height': 0.15416666666666667},
#     {'class_id': 1,
#      'x_center': 0.3140625,
#      'y_center': 0.25833333333333336,
#      'width': 0.14375,
#      'height': 0.20833333333333334},
#     {'class_id': 1,
#      'x_center': 0.08984375,
#      'y_center': 0.25625,
#      'width': 0.1453125,
#      'height': 0.1625},
#     {'class_id': 1,
#      'x_center': 0.91640625,
#      'y_center': 0.18541666666666667,
#      'width': 0.1640625,
#      'height': 0.20833333333333334},
#     {'class_id': 1,
#      'x_center': 0.92734375,
#      'y_center': 0.5104166666666666,
#      'width': 0.1453125,
#      'height': 0.20833333333333334},
#     {'class_id': 1,
#      'x_center': 0.67890625,
#      'y_center': 0.12708333333333333,
#      'width': 0.1453125,
#      'height': 0.20833333333333334},
#     {'class_id': 1,
#      'x_center': 0.33984375,
#      'y_center': 0.46875,
#      'width': 0.1453125,
#      'height': 0.20833333333333334},
#     {'class_id': 1,
#      'x_center': 0.4953125,
#      'y_center': 0.0875,
#      'width': 0.178125,
#      'height': 0.17083333333333334},
#     {'class_id': 1,
#      'x_center': 0.446875,
#      'y_center': 0.2760416666666667,
#      'width': 0.178125,
#      'height': 0.17291666666666666},
#     {'class_id': 1,
#      'x_center': 0.19765625,
#      'y_center': 0.39479166666666665,
#      'width': 0.1796875,
#      'height': 0.18958333333333333},
#     {'class_id': 1,
#      'x_center': 0.840625,
#      'y_center': 0.37604166666666666,
#      'width': 0.175,
#      'height': 0.20625},
#     {'class_id': 1,
#      'x_center': 0.65,
#      'y_center': 0.2760416666666667,
#      'width': 0.15,
#      'height': 0.18125}]},
#   {'filepath': 'BloodImage_00001.jpg',
#    'width': 640,
#    'height': 480,
#    'bboxes': [{'class_id': 0,
#      'x_center': 0.2765625,
#      'y_center': 0.828125,
#      'width': 0.340625,
#      'height': 0.34375},
#     {'class_id': 1,
#      'x_center': 0.61875,
#      'y_center': 0.8489583333333334,
#      'width': 0.15625,
#      'height': 0.19375},
#     {'class_id': 1,
#      'x_center': 0.15546875,
#      'y_center': 0.4979166666666667,
#      'width': 0.1453125,
#      'height': 0.25},
#     {'class_id': 1,
#      'x_center': 0.76953125,
#      'y_center': 0.9166666666666666,
#      'width': 0.1359375,
#      'height': 0.16666666666666666},
#     {'class_id': 1,
#      'x_center': 0.78828125,
#      'y_center': 0.35833333333333334,
#      'width': 0.1359375,
#      'height': 0.16666666666666666},
#     {'class_id': 1,
#      'x_center': 0.77734375,
#      'y_center': 0.6979166666666666,
#      'width': 0.1359375,
#      'height': 0.16666666666666666},
#     {'class_id': 1,
#      'x_center': 0.72265625,
#      'y_center': 0.69375,
#      'width': 0.1421875,
#      'height': 0.20833333333333334},
#     {'class_id': 1,
#      'x_center': 0.50546875,
#      'y_center': 0.8260416666666667,
#      'width': 0.1421875,
#      'height': 0.22708333333333333},
#     {'class_id': 1,
#      'x_center': 0.92265625,
#      'y_center': 0.23020833333333332,
#      'width': 0.1421875,
#      'height': 0.20208333333333334},
#     {'class_id': 1,
#      'x_center': 0.82890625,
#      'y_center': 0.290625,
#      'width': 0.1421875,
#      'height': 0.20208333333333334},
#     {'class_id': 1,
#      'x_center': 0.6359375,
#      'y_center': 0.44166666666666665,
#      'width': 0.096875,
#      'height': 0.17083333333333334},
#     {'class_id': 1,
#      'x_center': 0.565625,
#      'y_center': 0.4666666666666667,
#      'width': 0.103125,
#      'height': 0.19583333333333333},
#     {'class_id': 1,
#      'x_center': 0.5453125,
#      'y_center': 0.23645833333333333,
#      'width': 0.18125,
#      'height': 0.22708333333333333},
#     {'class_id': 1,
#      'x_center': 0.54921875,
#      'y_center': 0.071875,
#      'width': 0.1640625,
#      'height': 0.13958333333333334},
#     {'class_id': 1,
#      'x_center': 0.62109375,
#      'y_center': 0.17083333333333334,
#      'width': 0.1609375,
#      'height': 0.23333333333333334},
#     {'class_id': 1,
#      'x_center': 0.29296875,
#      'y_center': 0.1,
#      'width': 0.1671875,
#      'height': 0.19583333333333333},
#     {'class_id': 1,
#      'x_center': 0.07734375,
#      'y_center': 0.21041666666666667,
#      'width': 0.1515625,
#      'height': 0.2625},
#     {'class_id': 1,
#      'x_center': 0.3296875,
#      'y_center': 0.44166666666666665,
#      'width': 0.14375,
#      'height': 0.21666666666666667},
#     {'class_id': 1,
#      'x_center': 0.8046875,
#      'y_center': 0.55,
#      'width': 0.159375,
#      'height': 0.22916666666666666}]},
#   {'filepath': 'BloodImage_00002.jpg',
#    'width': 640,
#    'height': 480,
#    'bboxes': [{'class_id': 1,
#      'x_center': 0.709375,
#      'y_center': 0.30833333333333335,
#      'width': 0.215625,
#      'height': 0.20833333333333334},
#     {'class_id': 1,
#      'x_center': 0.68984375,
#      'y_center': 0.44166666666666665,
#      'width': 0.1796875,
#      'height': 0.2},
#     {'class_id': 1,
#      'x_center': 0.25390625,
#      'y_center': 0.35625,
#      'width': 0.1921875,
#      'height': 0.2125},
#     {'class_id': 1,
#      'x_center': 0.284375,
#      'y_center': 0.8197916666666667,
#      'width': 0.1625,
#      'height': 0.20625},
#     {'class_id': 1,
#      'x_center': 0.32421875,
#      'y_center': 0.896875,
#      'width': 0.1453125,
#      'height': 0.20625},
#     {'class_id': 1,
#      'x_center': 0.10703125,
#      'y_center': 0.5958333333333333,
#      'width': 0.1703125,
#      'height': 0.24166666666666667},
#     {'class_id': 1,
#      'x_center': 0.56328125,
#      'y_center': 0.73125,
#      'width': 0.1703125,
#      'height': 0.24166666666666667},
#     {'class_id': 1,
#      'x_center': 0.90859375,
#      'y_center': 0.3375,
#      'width': 0.1578125,
#      'height': 0.24583333333333332},
#     {'class_id': 1,
#      'x_center': 0.84765625,
#      'y_center': 0.6041666666666666,
#      'width': 0.1578125,
#      'height': 0.2375},
#     {'class_id': 1,
#      'x_center': 0.64765625,
#      'y_center': 0.6625,
#      'width': 0.1578125,
#      'height': 0.2375},
#     {'class_id': 1,
#      'x_center': 0.49140625,
#      'y_center': 0.24375,
#      'width': 0.1578125,
#      'height': 0.2375},
#     {'class_id': 1,
#      'x_center': 0.4828125,
#      'y_center': 0.4895833333333333,
#      'width': 0.1875,
#      'height': 0.25416666666666665},
#     {'class_id': 0,
#      'x_center': 0.6640625,
#      'y_center': 0.11145833333333334,
#      'width': 0.44375,
#      'height': 0.21875},
#     {'class_id': 1,
#      'x_center': 0.24296875,
#      'y_center': 0.103125,
#      'width': 0.1453125,
#      'height': 0.20208333333333334},
#     {'class_id': 1,
#      'x_center': 0.28359375,
#      'y_center': 0.23958333333333334,
#      'width': 0.1453125,
#      'height': 0.20416666666666666},
#     {'class_id': 1,
#      'x_center': 0.8359375,
#      'y_center': 0.8895833333333333,
#      'width': 0.171875,
#      'height': 0.22083333333333333}]},
#   {'filepath': 'BloodImage_00003.jpg',
#    'width': 640,
#    'height': 480,
#    'bboxes': [{'class_id': 0,
#      'x_center': 0.36796875,
#      'y_center': 0.27708333333333335,
#      'width': 0.3390625,
#      'height': 0.3875},
#     {'class_id': 1,
#      'x_center': 0.57890625,
#      'y_center': 0.3,
#      'width': 0.1671875,
#      'height': 0.2125},
#     {'class_id': 1,
#      'x_center': 0.6640625,
#      'y_center': 0.3958333333333333,
#      'width': 0.14375,
#      'height': 0.18333333333333332},
#     {'class_id': 1,
#      'x_center': 0.8734375,
#      'y_center': 0.5333333333333333,
#      'width': 0.171875,
#      'height': 0.19166666666666668},
#     {'class_id': 1,
#      'x_center': 0.7578125,
#      'y_center': 0.6427083333333333,
#      'width': 0.2125,
#      'height': 0.2520833333333333},
#     {'class_id': 1,
#      'x_center': 0.88203125,
#      'y_center': 0.15520833333333334,
#      'width': 0.1578125,
#      'height': 0.25625},
#     {'class_id': 1,
#      'x_center': 0.73203125,
#      'y_center': 0.09270833333333334,
#      'width': 0.1609375,
#      'height': 0.18125},
#     {'class_id': 1,
#      'x_center': 0.0625,
#      'y_center': 0.38125,
#      'width': 0.121875,
#      'height': 0.2375},
#     {'class_id': 1,
#      'x_center': 0.16015625,
#      'y_center': 0.540625,
#      'width': 0.1734375,
#      'height': 0.23958333333333334},
#     {'class_id': 1,
#      'x_center': 0.5765625,
#      'y_center': 0.6885416666666667,
#      'width': 0.171875,
#      'height': 0.19375},
#     {'class_id': 1,
#      'x_center': 0.66328125,
#      'y_center': 0.834375,
#      'width': 0.1859375,
#      'height': 0.21041666666666667},
#     {'class_id': 1,
#      'x_center': 0.06796875,
#      'y_center': 0.8135416666666667,
#      'width': 0.1328125,
#      'height': 0.18125},
#     {'class_id': 1,
#      'x_center': 0.18125,
#      'y_center': 0.9125,
#      'width': 0.209375,
#      'height': 0.175},
#     {'class_id': 1,
#      'x_center': 0.86640625,
#      'y_center': 0.8979166666666667,
#      'width': 0.1265625,
#      'height': 0.19166666666666668},
#     {'class_id': 1,
#      'x_center': 0.16171875,
#      'y_center': 0.28854166666666664,
#      'width': 0.1484375,
#      'height': 0.3020833333333333},
#     {'class_id': 1,
#      'x_center': 0.4265625,
#      'y_center': 0.646875,
#      'width': 0.1875,
#      'height': 0.23958333333333334},
#     {'class_id': 2,
#      'x_center': 0.55078125,
#      'y_center': 0.590625,
#      'width': 0.0546875,
#      'height': 0.06458333333333334}]},
#   {'filepath': 'BloodImage_00004.jpg',
#    'width': 640,
#    'height': 480,
#    'bboxes': [{'class_id': 0,
#      'x_center': 0.33828125,
#      'y_center': 0.4739583333333333,
#      'width': 0.3359375,
#      'height': 0.38958333333333334},
#     {'class_id': 1,
#      'x_center': 0.75,
#      'y_center': 0.590625,
#      'width': 0.15,
#      'height': 0.17291666666666666},
#     {'class_id': 1,
#      'x_center': 0.871875,
#      'y_center': 0.31979166666666664,
#      'width': 0.15,
#      'height': 0.17291666666666666},
#     {'class_id': 1,
#      'x_center': 0.840625,
#      'y_center': 0.8708333333333333,
#      'width': 0.175,
#      'height': 0.2375},
#     {'class_id': 1,
#      'x_center': 0.18828125,
#      'y_center': 0.6833333333333333,
#      'width': 0.1421875,
#      'height': 0.19583333333333333},
#     {'class_id': 1,
#      'x_center': 0.14453125,
#      'y_center': 0.065625,
#      'width': 0.1703125,
#      'height': 0.12708333333333333},
#     {'class_id': 1,
#      'x_center': 0.5296875,
#      'y_center': 0.17083333333333334,
#      'width': 0.159375,
#      'height': 0.20416666666666666},
#     {'class_id': 1,
#      'x_center': 0.7328125,
#      'y_center': 0.26145833333333335,
#      'width': 0.18125,
#      'height': 0.24791666666666667},
#     {'class_id': 1,
#      'x_center': 0.08046875,
#      'y_center': 0.2916666666666667,
#      'width': 0.1578125,
#      'height': 0.24166666666666667},
#     {'class_id': 1,
#      'x_center': 0.0640625,
#      'y_center': 0.6822916666666666,
#      'width': 0.125,
#      'height': 0.18541666666666667},
#     {'class_id': 1,
#      'x_center': 0.06171875,
#      'y_center': 0.7416666666666667,
#      'width': 0.1203125,
#      'height': 0.17083333333333334},
#     {'class_id': 1,
#      'x_center': 0.671875,
#      'y_center': 0.8625,
#      'width': 0.121875,
#      'height': 0.17083333333333334},
#     {'class_id': 2,
#      'x_center': 0.2265625,
#      'y_center': 0.13333333333333333,
#      'width': 0.05625,
#      'height': 0.07083333333333333}]},
#   {'filepath': 'BloodImage_00005.jpg',
#    'width': 640,
#    'height': 480,
#    'bboxes': [{'class_id': 1,
#      'x_center': 0.51484375,
#      'y_center': 0.35104166666666664,
#      'width': 0.1765625,
#      'height': 0.22291666666666668},
#     {'class_id': 1,
#      'x_center': 0.17578125,
#      'y_center': 0.3260416666666667,
#      'width': 0.1765625,
#      'height': 0.22291666666666668},
#     {'class_id': 1,
#      'x_center': 0.728125,
#      'y_center': 0.22083333333333333,
#      'width': 0.1625,
#      'height': 0.26666666666666666},
#     {'class_id': 1,
#      'x_center': 0.91875,
#      'y_center': 0.2875,
#      'width': 0.1625,
#      'height': 0.26666666666666666},
#     {'class_id': 1,
#      'x_center': 0.821875,
#      'y_center': 0.5354166666666667,
#      'width': 0.1625,
#      'height': 0.26666666666666666},
#     {'class_id': 1,
#      'x_center': 0.809375,
#      'y_center': 0.8354166666666667,
#      'width': 0.1625,
#      'height': 0.26666666666666666},
#     {'class_id': 1,
#      'x_center': 0.7375,
#      'y_center': 0.8666666666666667,
#      'width': 0.1625,
#      'height': 0.26666666666666666},
#     {'class_id': 1,
#      'x_center': 0.41328125,
#      'y_center': 0.4739583333333333,
#      'width': 0.1546875,
#      'height': 0.22291666666666668},
#     {'class_id': 1,
#      'x_center': 0.67109375,
#      'y_center': 0.48854166666666665,
#      'width': 0.1546875,
#      'height': 0.22291666666666668},
#     {'class_id': 1,
#      'x_center': 0.078125,
#      'y_center': 0.24479166666666666,
#      'width': 0.153125,
#      'height': 0.22291666666666668},
#     {'class_id': 1,
#      'x_center': 0.6,
#      'y_center': 0.09166666666666666,
#      'width': 0.1875,
#      'height': 0.17916666666666667},
#     {'class_id': 1,
#      'x_center': 0.353125,
#      'y_center': 0.07395833333333333,
#      'width': 0.2,
#      'height': 0.14375},
#     {'class_id': 1,
#      'x_center': 0.33828125,
#      'y_center': 0.453125,
#      'width': 0.1359375,
#      'height': 0.21875},
#     {'class_id': 1,
#      'x_center': 0.28515625,
#      'y_center': 0.5072916666666667,
#      'width': 0.1359375,
#      'height': 0.21875},
#     {'class_id': 1,
#      'x_center': 0.22890625,
#      'y_center': 0.5489583333333333,
#      'width': 0.1359375,
#      'height': 0.21875},
#     {'class_id': 1,
#      'x_center': 0.11328125,
#      'y_center': 0.590625,
#      'width': 0.1359375,
#      'height': 0.21875},
#     {'class_id': 2,
#      'x_center': 0.29453125,
#      'y_center': 0.171875,
#      'width': 0.0578125,
#      'height': 0.07291666666666667},
#     {'class_id': 2,
#      'x_center': 0.03828125,
#      'y_center': 0.871875,
#      'width': 0.0578125,
#      'height': 0.07291666666666667},
#     {'class_id': 2,
#      'x_center': 0.22265625,
#      'y_center': 0.671875,
#      'width': 0.0578125,
#      'height': 0.07291666666666667},
#     {'class_id': 0,
#      'x_center': 0.52421875,
#      'y_center': 0.8,
#      'width': 0.3296875,
#      'height': 0.4},
#     {'class_id': 1,
#      'x_center': 0.30234375,
#      'y_center': 0.7510416666666667,
#      'width': 0.1328125,
#      'height': 0.2604166666666667},
#     {'class_id': 1,
#      'x_center': 0.18515625,
#      'y_center': 0.12083333333333333,
#      'width': 0.1734375,
#      'height': 0.1625}]},
#   {'filepath': 'BloodImage_00006.jpg',
#    'width': 640,
#    'height': 480,
#    'bboxes': [{'class_id': 0,
#      'x_center': 0.31796875,
#      'y_center': 0.5729166666666666,
#      'width': 0.2703125,
#      'height': 0.3541666666666667},
#     {'class_id': 2,
#      'x_center': 0.171875,
#      'y_center': 0.421875,
#      'width': 0.065625,
#      'height': 0.07708333333333334},
#     {'class_id': 2,
#      'x_center': 0.134375,
#      'y_center': 0.46145833333333336,
#      'width': 0.065625,
#      'height': 0.07708333333333334},
#     {'class_id': 2,
#      'x_center': 0.55078125,
#      'y_center': 0.03229166666666667,
#      'width': 0.0609375,
#      'height': 0.06041666666666667},
#     {'class_id': 1,
#      'x_center': 0.21953125,
#      'y_center': 0.85,
#      'width': 0.1921875,
#      'height': 0.2125},
#     {'class_id': 1,
#      'x_center': 0.87109375,
#      'y_center': 0.11979166666666667,
#      'width': 0.1953125,
#      'height': 0.23541666666666666},
#     {'class_id': 1,
#      'x_center': 0.64765625,
#      'y_center': 0.8229166666666666,
#      'width': 0.1921875,
#      'height': 0.2833333333333333},
#     {'class_id': 1,
#      'x_center': 0.7921875,
#      'y_center': 0.7416666666666667,
#      'width': 0.18125,
#      'height': 0.15416666666666667},
#     {'class_id': 1,
#      'x_center': 0.5421875,
#      'y_center': 0.3104166666666667,
#      'width': 0.175,
#      'height': 0.1875},
#     {'class_id': 1,
#      'x_center': 0.4171875,
#      'y_center': 0.2520833333333333,
#      'width': 0.175,
#      'height': 0.1875},
#     {'class_id': 1,
#      'x_center': 0.4109375,
#      'y_center': 0.8229166666666666,
#      'width': 0.175,
#      'height': 0.1875},
#     {'class_id': 1,
#      'x_center': 0.4875,
#      'y_center': 0.7302083333333333,
#      'width': 0.184375,
#      'height': 0.21875},
#     {'class_id': 1,
#      'x_center': 0.92578125,
#      'y_center': 0.8833333333333333,
#      'width': 0.1453125,
#      'height': 0.23333333333333334},
#     {'class_id': 1,
#      'x_center': 0.85859375,
#      'y_center': 0.5729166666666666,
#      'width': 0.2109375,
#      'height': 0.21666666666666667},
#     {'class_id': 1,
#      'x_center': 0.8765625,
#      'y_center': 0.42291666666666666,
#      'width': 0.18125,
#      'height': 0.17916666666666667},
#     {'class_id': 1,
#      'x_center': 0.6734375,
#      'y_center': 0.3927083333333333,
#      'width': 0.18125,
#      'height': 0.19375},
#     {'class_id': 1,
#      'x_center': 0.26796875,
#      'y_center': 0.35104166666666664,
#      'width': 0.1984375,
#      'height': 0.19791666666666666},
#     {'class_id': 1,
#      'x_center': 0.12421875,
#      'y_center': 0.221875,
#      'width': 0.1984375,
#      'height': 0.19791666666666666}]},
#   {'filepath': 'BloodImage_00007.jpg',
#    'width': 640,
#    'height': 480,
#    'bboxes': [{'class_id': 0,
#      'x_center': 0.453125,
#      'y_center': 0.3927083333333333,
#      'width': 0.303125,
#      'height': 0.40208333333333335},
#     {'class_id': 1,
#      'x_center': 0.11796875,
#      'y_center': 0.7291666666666666,
#      'width': 0.1828125,
#      'height': 0.21666666666666667},
#     {'class_id': 1,
#      'x_center': 0.18671875,
#      'y_center': 0.8864583333333333,
#      'width': 0.1734375,
#      'height': 0.22291666666666668},
#     {'class_id': 1,
#      'x_center': 0.27265625,
#      'y_center': 0.7989583333333333,
#      'width': 0.1734375,
#      'height': 0.22291666666666668},
#     {'class_id': 1,
#      'x_center': 0.334375,
#      'y_center': 0.665625,
#      'width': 0.140625,
#      'height': 0.22708333333333333},
#     {'class_id': 1,
#      'x_center': 0.36875,
#      'y_center': 0.7197916666666667,
#      'width': 0.140625,
#      'height': 0.22708333333333333},
#     {'class_id': 1,
#      'x_center': 0.403125,
#      'y_center': 0.7489583333333333,
#      'width': 0.140625,
#      'height': 0.22708333333333333},
#     {'class_id': 1,
#      'x_center': 0.45625,
#      'y_center': 0.7697916666666667,
#      'width': 0.140625,
#      'height': 0.22708333333333333},
#     {'class_id': 1,
#      'x_center': 0.85625,
#      'y_center': 0.73125,
#      'width': 0.165625,
#      'height': 0.2125},
#     {'class_id': 1,
#      'x_center': 0.9171875,
#      'y_center': 0.8791666666666667,
#      'width': 0.165625,
#      'height': 0.2125},
#     {'class_id': 1,
#      'x_center': 0.8796875,
#      'y_center': 0.12083333333333333,
#      'width': 0.165625,
#      'height': 0.2125},
#     {'class_id': 1,
#      'x_center': 0.9015625,
#      'y_center': 0.20416666666666666,
#      'width': 0.19375,
#      'height': 0.225},
#     {'class_id': 1,
#      'x_center': 0.125,
#      'y_center': 0.37083333333333335,
#      'width': 0.19375,
#      'height': 0.225},
#     {'class_id': 1,
#      'x_center': 0.20625,
#      'y_center': 0.24375,
#      'width': 0.19375,
#      'height': 0.225},
#     {'class_id': 1,
#      'x_center': 0.1265625,
#      'y_center': 0.17291666666666666,
#      'width': 0.19375,
#      'height': 0.225},
#     {'class_id': 1,
#      'x_center': 0.5171875,
#      'y_center': 0.075,
#      'width': 0.190625,
#      'height': 0.14583333333333334},
#     {'class_id': 1,
#      'x_center': 0.4640625,
#      'y_center': 0.9447916666666667,
#      'width': 0.134375,
#      'height': 0.11041666666666666},
#     {'class_id': 1,
#      'x_center': 0.53046875,
#      'y_center': 0.9520833333333333,
#      'width': 0.1296875,
#      'height': 0.09583333333333334}]},
#   {'filepath': 'BloodImage_00008.jpg',
#    'width': 640,
#    'height': 480,
#    'bboxes': [{'class_id': 0,
#      'x_center': 0.24921875,
#      'y_center': 0.5875,
#      'width': 0.3671875,
#      'height': 0.4125},
#     {'class_id': 1,
#      'x_center': 0.71640625,
#      'y_center': 0.575,
#      'width': 0.1890625,
#      'height': 0.225},
#     {'class_id': 1,
#      'x_center': 0.88359375,
#      'y_center': 0.32708333333333334,
#      'width': 0.1890625,
#      'height': 0.225},
#     {'class_id': 1,
#      'x_center': 0.6546875,
#      'y_center': 0.7583333333333333,
#      'width': 0.165625,
#      'height': 0.20416666666666666},
#     {'class_id': 1,
#      'x_center': 0.7953125,
#      'y_center': 0.7520833333333333,
#      'width': 0.165625,
#      'height': 0.20416666666666666},
#     {'class_id': 1,
#      'x_center': 0.9015625,
#      'y_center': 0.6229166666666667,
#      'width': 0.165625,
#      'height': 0.20416666666666666},
#     {'class_id': 1,
#      'x_center': 0.9171875,
#      'y_center': 0.8,
#      'width': 0.165625,
#      'height': 0.20416666666666666},
#     {'class_id': 1,
#      'x_center': 0.634375,
#      'y_center': 0.19166666666666668,
#      'width': 0.165625,
#      'height': 0.20416666666666666},
#     {'class_id': 1,
#      'x_center': 0.5765625,
#      'y_center': 0.19166666666666668,
#      'width': 0.165625,
#      'height': 0.20416666666666666},
#     {'class_id': 1,
#      'x_center': 0.496875,
#      'y_center': 0.15416666666666667,
#      'width': 0.165625,
#      'height': 0.20416666666666666},
#     {'class_id': 1,
#      'x_center': 0.428125,
#      'y_center': 0.13958333333333334,
#      'width': 0.165625,
#      'height': 0.20416666666666666},
#     {'class_id': 1,
#      'x_center': 0.2578125,
#      'y_center': 0.08958333333333333,
#      'width': 0.175,
#      'height': 0.175},
#     {'class_id': 1,
#      'x_center': 0.07578125,
#      'y_center': 0.484375,
#      'width': 0.1484375,
#      'height': 0.27708333333333335},
#     {'class_id': 1,
#      'x_center': 0.490625,
#      'y_center': 0.91875,
#      'width': 0.159375,
#      'height': 0.1625},
#     {'class_id': 1,
#      'x_center': 0.3578125,
#      'y_center': 0.91875,
#      'width': 0.159375,
#      'height': 0.1625},
#     {'class_id': 1,
#      'x_center': 0.08046875,
#      'y_center': 0.08125,
#      'width': 0.1578125,
#      'height': 0.15833333333333333},
#     {'class_id': 1,
#      'x_center': 0.39765625,
#      'y_center': 0.3645833333333333,
#      'width': 0.1828125,
#      'height': 0.16666666666666666},
#     {'class_id': 1,
#      'x_center': 0.8234375,
#      'y_center': 0.9083333333333333,
#      'width': 0.25,
#      'height': 0.18333333333333332},
#     {'class_id': 1,
#      'x_center': 0.2984375,
#      'y_center': 0.24375,
#      'width': 0.134375,
#      'height': 0.22916666666666666},
#     {'class_id': 1,
#      'x_center': 0.7828125,
#      'y_center': 0.08958333333333333,
#      'width': 0.196875,
#      'height': 0.175}]},
#   {'filepath': 'BloodImage_00009.jpg',
#    'width': 640,
#    'height': 480,
#    'bboxes': [{'class_id': 0,
#      'x_center': 0.2171875,
#      'y_center': 0.5833333333333334,
#      'width': 0.3625,
#      'height': 0.5958333333333333},
#     {'class_id': 1,
#      'x_center': 0.79375,
#      'y_center': 0.778125,
#      'width': 0.209375,
#      'height': 0.20625},
#     {'class_id': 1,
#      'x_center': 0.65625,
#      'y_center': 0.490625,
#      'width': 0.15,
#      'height': 0.18125},
#     {'class_id': 1,
#      'x_center': 0.5515625,
#      'y_center': 0.534375,
#      'width': 0.15,
#      'height': 0.18125},
#     {'class_id': 1,
#      'x_center': 0.4296875,
#      'y_center': 0.7572916666666667,
#      'width': 0.153125,
#      'height': 0.3145833333333333},
#     {'class_id': 1,
#      'x_center': 0.56328125,
#      'y_center': 0.7625,
#      'width': 0.1484375,
#      'height': 0.2},
#     {'class_id': 1,
#      'x_center': 0.51484375,
#      'y_center': 0.9,
#      'width': 0.1484375,
#      'height': 0.2},
#     {'class_id': 1,
#      'x_center': 0.79140625,
#      'y_center': 0.315625,
#      'width': 0.1890625,
#      'height': 0.22708333333333333},
#     {'class_id': 1,
#      'x_center': 0.78203125,
#      'y_center': 0.10104166666666667,
#      'width': 0.1890625,
#      'height': 0.19791666666666666},
#     {'class_id': 1,
#      'x_center': 0.42578125,
#      'y_center': 0.3177083333333333,
#      'width': 0.1828125,
#      'height': 0.18958333333333333},
#     {'class_id': 1,
#      'x_center': 0.57265625,
#      'y_center': 0.30833333333333335,
#      'width': 0.2140625,
#      'height': 0.2625},
#     {'class_id': 1,
#      'x_center': 0.109375,
#      'y_center': 0.284375,
#      'width': 0.196875,
#      'height': 0.2520833333333333},
#     {'class_id': 1,
#      'x_center': 0.090625,
#      'y_center': 0.09895833333333333,
#      'width': 0.178125,
#      'height': 0.19375},
#     {'class_id': 1,
#      'x_center': 0.53125,
#      'y_center': 0.06875,
#      'width': 0.16875,
#      'height': 0.13333333333333333},
#     {'class_id': 1,
#      'x_center': 0.34609375,
#      'y_center': 0.14583333333333334,
#      'width': 0.2109375,
#      'height': 0.2375},
#     {'class_id': 2,
#      'x_center': 0.73828125,
#      'y_center': 0.9,
#      'width': 0.0640625,
#      'height': 0.07083333333333333},
#     {'class_id': 1,
#      'x_center': 0.8234375,
#      'y_center': 0.41354166666666664,
#      'width': 0.15,
#      'height': 0.18125},
#     {'class_id': 1,
#      'x_center': 0.2859375,
#      'y_center': 0.909375,
#      'width': 0.15,
#      'height': 0.18125}]},
#   {'filepath': 'BloodImage_00010.jpg',
#    'width': 640,
#    'height': 480,
#    'bboxes': [{'class_id': 0,
#      'x_center': 0.17734375,
#      'y_center': 0.6770833333333334,
#      'width': 0.2828125,
#      'height': 0.4},
#     {'class_id': 0,
#      'x_center': 0.58515625,
#      'y_center': 0.753125,
#      'width': 0.4234375,
#      'height': 0.45208333333333334},
#     {'class_id': 1,
#      'x_center': 0.340625,
#      'y_center': 0.565625,
#      'width': 0.159375,
#      'height': 0.24791666666666667},
#     {'class_id': 1,
#      'x_center': 0.18671875,
#      'y_center': 0.396875,
#      'width': 0.1578125,
#      'height': 0.21875},
#     {'class_id': 1,
#      'x_center': 0.13203125,
#      'y_center': 0.265625,
#      'width': 0.1296875,
#      'height': 0.18125},
#     {'class_id': 1,
#      'x_center': 0.49453125,
#      'y_center': 0.43645833333333334,
#      'width': 0.1296875,
#      'height': 0.18125},
#     {'class_id': 1,
#      'x_center': 0.55078125,
#      'y_center': 0.4635416666666667,
#      'width': 0.1296875,
#      'height': 0.18125},
#     {'class_id': 1,
#      'x_center': 0.48203125,
#      'y_center': 0.234375,
#      'width': 0.1296875,
#      'height': 0.18125},
#     {'class_id': 1,
#      'x_center': 0.54453125,
#      'y_center': 0.246875,
#      'width': 0.1296875,
#      'height': 0.18125},
#     {'class_id': 1,
#      'x_center': 0.59453125,
#      'y_center': 0.25729166666666664,
#      'width': 0.1296875,
#      'height': 0.18125},
#     {'class_id': 1,
#      'x_center': 0.7859375,
#      'y_center': 0.071875,
#      'width': 0.146875,
#      'height': 0.13958333333333334},
#     {'class_id': 1,
#      'x_center': 0.58046875,
#      'y_center': 0.07291666666666667,
#      'width': 0.1796875,
#      'height': 0.14166666666666666},
#     {'class_id': 1,
#      'x_center': 0.3984375,
#      'y_center': 0.04583333333333333,
#      'width': 0.171875,
#      'height': 0.0875},
#     {'class_id': 1,
#      'x_center': 0.090625,
#      'y_center': 0.08333333333333333,
#      'width': 0.13125,
#      'height': 0.1625},
#     {'class_id': 1,
#      'x_center': 0.7375,
#      'y_center': 0.2760416666666667,
#      'width': 0.20625,
#      'height': 0.21875},
#     {'class_id': 1,
#      'x_center': 0.9375,
#      'y_center': 0.6052083333333333,
#      'width': 0.125,
#      'height': 0.22708333333333333},
#     {'class_id': 1,
#      'x_center': 0.94609375,
#      'y_center': 0.45208333333333334,
#      'width': 0.1078125,
#      'height': 0.17916666666666667},
#     {'class_id': 1,
#      'x_center': 0.9421875,
#      'y_center': 0.24583333333333332,
#      'width': 0.115625,
#      'height': 0.175}]},
#   {'filepath': 'BloodImage_00011.jpg',
#    'width': 640,
#    'height': 480,
#    'bboxes': [{'class_id': 0,
#      'x_center': 0.32265625,
#      'y_center': 0.46979166666666666,
#      'width': 0.3046875,
#      'height': 0.44375},
#     {'class_id': 1,
#      'x_center': 0.63828125,
#      'y_center': 0.5,
#      'width': 0.1390625,
#      'height': 0.1625},
#     {'class_id': 1,
#      'x_center': 0.71953125,
#      'y_center': 0.42916666666666664,
#      'width': 0.1390625,
#      'height': 0.1625},
#     {'class_id': 1,
#      'x_center': 0.78671875,
#      'y_center': 0.3125,
#      'width': 0.1390625,
#      'height': 0.1625},
#     {'class_id': 1,
#      'x_center': 0.79140625,
#      'y_center': 0.39791666666666664,
#      'width': 0.1390625,
#      'height': 0.20416666666666666},
#     {'class_id': 1,
#      'x_center': 0.84453125,
#      'y_center': 0.4197916666666667,
#      'width': 0.1109375,
#      'height': 0.16041666666666668},
#     {'class_id': 1,
#      'x_center': 0.82734375,
#      'y_center': 0.590625,
#      'width': 0.1671875,
#      'height': 0.20208333333333334},
#     {'class_id': 1,
#      'x_center': 0.10234375,
#      'y_center': 0.734375,
#      'width': 0.1609375,
#      'height': 0.23541666666666666},
#     {'class_id': 1,
#      'x_center': 0.41640625,
#      'y_center': 0.125,
#      'width': 0.1453125,
#      'height': 0.21666666666666667},
#     {'class_id': 1,
#      'x_center': 0.60703125,
#      'y_center': 0.20833333333333334,
#      'width': 0.1453125,
#      'height': 0.21666666666666667},
#     {'class_id': 1,
#      'x_center': 0.58671875,
#      'y_center': 0.26458333333333334,
#      'width': 0.1828125,
#      'height': 0.22083333333333333},
#     {'class_id': 1,
#      'x_center': 0.4765625,
#      'y_center': 0.2604166666666667,
#      'width': 0.146875,
#      'height': 0.19166666666666668},
#     {'class_id': 1,
#      'x_center': 0.7046875,
#      'y_center': 0.7135416666666666,
#      'width': 0.146875,
#      'height': 0.21458333333333332},
#     {'class_id': 1,
#      'x_center': 0.384375,
#      'y_center': 0.809375,
#      'width': 0.146875,
#      'height': 0.21458333333333332},
#     {'class_id': 1,
#      'x_center': 0.23125,
#      'y_center': 0.884375,
#      'width': 0.196875,
#      'height': 0.21875},
#     {'class_id': 1,
#      'x_center': 0.246875,
#      'y_center': 0.12291666666666666,
#      'width': 0.16875,
#      'height': 0.24166666666666667},
#     {'class_id': 2,
#      'x_center': 0.16171875,
#      'y_center': 0.36354166666666665,
#      'width': 0.0578125,
#      'height': 0.08958333333333333},
#     {'class_id': 1,
#      'x_center': 0.48125,
#      'y_center': 0.9364583333333333,
#      'width': 0.14375,
#      'height': 0.12708333333333333},
#     {'class_id': 1,
#      'x_center': 0.07421875,
#      'y_center': 0.2677083333333333,
#      'width': 0.1453125,
#      'height': 0.21458333333333332}]},
#   {'filepath': 'BloodImage_00012.jpg',
#    'width': 640,
#    'height': 480,
#    'bboxes': [{'class_id': 0,
#      'x_center': 0.1796875,
#      'y_center': 0.56875,
#      'width': 0.353125,
#      'height': 0.35833333333333334},
#     {'class_id': 1,
#      'x_center': 0.64375,
#      'y_center': 0.40208333333333335,
#      'width': 0.196875,
#      'height': 0.19583333333333333},
#     {'class_id': 1,
#      'x_center': 0.671875,
#      'y_center': 0.5458333333333333,
#      'width': 0.165625,
#      'height': 0.21666666666666667},
#     {'class_id': 1,
#      'x_center': 0.709375,
#      'y_center': 0.73125,
#      'width': 0.165625,
#      'height': 0.21666666666666667},
#     {'class_id': 1,
#      'x_center': 0.5328125,
#      'y_center': 0.6958333333333333,
#      'width': 0.140625,
#      'height': 0.22083333333333333},
#     {'class_id': 1,
#      'x_center': 0.46484375,
#      'y_center': 0.78125,
#      'width': 0.1453125,
#      'height': 0.26666666666666666},
#     {'class_id': 1,
#      'x_center': 0.3375,
#      'y_center': 0.7354166666666667,
#      'width': 0.15,
#      'height': 0.20416666666666666},
#     {'class_id': 1,
#      'x_center': 0.10859375,
#      'y_center': 0.8010416666666667,
#      'width': 0.1734375,
#      'height': 0.20625},
#     {'class_id': 1,
#      'x_center': 0.29453125,
#      'y_center': 0.9083333333333333,
#      'width': 0.1953125,
#      'height': 0.17916666666666667},
#     {'class_id': 1,
#      'x_center': 0.57890625,
#      'y_center': 0.8885416666666667,
#      'width': 0.1296875,
#      'height': 0.21041666666666667},
#     {'class_id': 1,
#      'x_center': 0.89140625,
#      'y_center': 0.8447916666666667,
#      'width': 0.1609375,
#      'height': 0.20625},
#     {'class_id': 1,
#      'x_center': 0.82421875,
#      'y_center': 0.6385416666666667,
#      'width': 0.1609375,
#      'height': 0.20625},
#     {'class_id': 1,
#      'x_center': 0.84453125,
#      'y_center': 0.5052083333333334,
#      'width': 0.1609375,
#      'height': 0.20625},
#     {'class_id': 1,
#      'x_center': 0.940625,
#      'y_center': 0.5833333333333334,
#      'width': 0.11875,
#      'height': 0.2},
#     {'class_id': 2,
#      'x_center': 0.6875,
#      'y_center': 0.878125,
#      'width': 0.071875,
#      'height': 0.07708333333333334},
#     {'class_id': 2,
#      'x_center': 0.584375,
#      'y_center': 0.13020833333333334,
#      'width': 0.071875,
#      'height': 0.07708333333333334},
#     {'class_id': 1,
#      'x_center': 0.40859375,
#      'y_center': 0.13229166666666667,
#      'width': 0.1296875,
#      'height': 0.18125},
#     {'class_id': 1,
#      'x_center': 0.859375,
#      'y_center': 0.29791666666666666,
#      'width': 0.171875,
#      'height': 0.25416666666666665},
#     {'class_id': 1,
#      'x_center': 0.53125,
#      'y_center': 0.9489583333333333,
#      'width': 0.128125,
#      'height': 0.10208333333333333}]},
#   {'filepath': 'BloodImage_00013.jpg',
#    'width': 640,
#    'height': 480,
#    'bboxes': [{'class_id': 0,
#      'x_center': 0.21015625,
#      'y_center': 0.6395833333333333,
#      'width': 0.3234375,
#      'height': 0.4125},
#     {'class_id': 1,
#      'x_center': 0.4890625,
#      'y_center': 0.703125,
#      'width': 0.18125,
#      'height': 0.22708333333333333},
#     {'class_id': 1,
#      'x_center': 0.7203125,
#      'y_center': 0.7375,
#      'width': 0.175,
#      'height': 0.275},
#     {'class_id': 1,
#      'x_center': 0.66796875,
#      'y_center': 0.3125,
#      'width': 0.1828125,
#      'height': 0.30416666666666664},
#     {'class_id': 1,
#      'x_center': 0.2265625,
#      'y_center': 0.2989583333333333,
#      'width': 0.171875,
#      'height': 0.18958333333333333},
#     {'class_id': 1,
#      'x_center': 0.403125,
#      'y_center': 0.8552083333333333,
#      'width': 0.171875,
#      'height': 0.18958333333333333},
#     {'class_id': 1,
#      'x_center': 0.58203125,
#      'y_center': 0.9125,
#      'width': 0.1703125,
#      'height': 0.175},
#     {'class_id': 1,
#      'x_center': 0.94765625,
#      'y_center': 0.459375,
#      'width': 0.1015625,
#      'height': 0.2520833333333333},
#     {'class_id': 1,
#      'x_center': 0.8046875,
#      'y_center': 0.240625,
#      'width': 0.153125,
#      'height': 0.24375},
#     {'class_id': 1,
#      'x_center': 0.92578125,
#      'y_center': 0.2,
#      'width': 0.1421875,
#      'height': 0.2},
#     {'class_id': 1,
#      'x_center': 0.85859375,
#      'y_center': 0.5614583333333333,
#      'width': 0.1546875,
#      'height': 0.23125},
#     {'class_id': 1,
#      'x_center': 0.37734375,
#      'y_center': 0.13541666666666666,
#      'width': 0.1796875,
#      'height': 0.22083333333333333},
#     {'class_id': 1,
#      'x_center': 0.25390625,
#      'y_center': 0.18125,
#      'width': 0.1796875,
#      'height': 0.22083333333333333},
#     {'class_id': 1,
#      'x_center': 0.7890625,
#      'y_center': 0.9208333333333333,
#      'width': 0.15625,
#      'height': 0.15833333333333333},
#     {'class_id': 1,
#      'x_center': 0.584375,
#      'y_center': 0.9166666666666666,
#      'width': 0.15625,
#      'height': 0.15833333333333333}]},
#   {'filepath': 'BloodImage_00014.jpg',
#    'width': 640,
#    'height': 480,
#    'bboxes': [{'class_id': 0,
#      'x_center': 0.48046875,
#      'y_center': 0.5875,
#      'width': 0.2234375,
#      'height': 0.29583333333333334},
#     {'class_id': 1,
#      'x_center': 0.325,
#      'y_center': 0.38958333333333334,
#      'width': 0.15625,
#      'height': 0.19583333333333333},
#     {'class_id': 1,
#      'x_center': 0.21484375,
#      'y_center': 0.8010416666666667,
#      'width': 0.1859375,
#      'height': 0.21041666666666667},
#     {'class_id': 1,
#      'x_center': 0.05703125,
#      'y_center': 0.39479166666666665,
#      'width': 0.1109375,
#      'height': 0.21875},
#     {'class_id': 1,
#      'x_center': 0.14453125,
#      'y_center': 0.28958333333333336,
#      'width': 0.1859375,
#      'height': 0.20833333333333334},
#     {'class_id': 1,
#      'x_center': 0.17578125,
#      'y_center': 0.13541666666666666,
#      'width': 0.1859375,
#      'height': 0.20833333333333334},
#     {'class_id': 1,
#      'x_center': 0.5796875,
#      'y_center': 0.09791666666666667,
#      'width': 0.109375,
#      'height': 0.19166666666666668},
#     {'class_id': 1,
#      'x_center': 0.56171875,
#      'y_center': 0.26145833333333335,
#      'width': 0.1953125,
#      'height': 0.19791666666666666},
#     {'class_id': 1,
#      'x_center': 0.45,
#      'y_center': 0.278125,
#      'width': 0.2,
#      'height': 0.23958333333333334},
#     {'class_id': 1,
#      'x_center': 0.42890625,
#      'y_center': 0.8958333333333334,
#      'width': 0.1859375,
#      'height': 0.20833333333333334},
#     {'class_id': 1,
#      'x_center': 0.62734375,
#      'y_center': 0.725,
#      'width': 0.1421875,
#      'height': 0.1875},
#     {'class_id': 1,
#      'x_center': 0.68515625,
#      'y_center': 0.5416666666666666,
#      'width': 0.1421875,
#      'height': 0.1875},
#     {'class_id': 1,
#      'x_center': 0.77578125,
#      'y_center': 0.9229166666666667,
#      'width': 0.1515625,
#      'height': 0.15416666666666667},
#     {'class_id': 1,
#      'x_center': 0.76953125,
#      'y_center': 0.10729166666666666,
#      'width': 0.1921875,
#      'height': 0.21041666666666667},
#     {'class_id': 2,
#      'x_center': 0.59921875,
#      'y_center': 0.8510416666666667,
#      'width': 0.0671875,
#      'height': 0.08125},
#     {'class_id': 2,
#      'x_center': 0.39765625,
#      'y_center': 0.7489583333333333,
#      'width': 0.0671875,
#      'height': 0.08125},
#     {'class_id': 1,
#      'x_center': 0.915625,
#      'y_center': 0.7166666666666667,
#      'width': 0.1375,
#      'height': 0.22916666666666666},
#     {'class_id': 1,
#      'x_center': 0.95234375,
#      'y_center': 0.38229166666666664,
#      'width': 0.0953125,
#      'height': 0.21875},
#     {'class_id': 1,
#      'x_center': 0.89296875,
#      'y_center': 0.25625,
#      'width': 0.1453125,
#      'height': 0.22083333333333333}]},
#   {'filepath': 'BloodImage_00015.jpg',
#    'width': 640,
#    'height': 480,
#    'bboxes': [{'class_id': 0,
#      'x_center': 0.3953125,
#      'y_center': 0.25416666666666665,
#      'width': 0.3375,
#      'height': 0.49166666666666664},
#     {'class_id': 1,
#      'x_center': 0.61015625,
#      'y_center': 0.38229166666666664,
#      'width': 0.1171875,
#      'height': 0.20208333333333334},
#     {'class_id': 1,
#      'x_center': 0.6265625,
#      'y_center': 0.14583333333333334,
#      'width': 0.146875,
#      'height': 0.24166666666666667},
#     {'class_id': 1,
#      'x_center': 0.765625,
#      'y_center': 0.24791666666666667,
#      'width': 0.15625,
#      'height': 0.17083333333333334},
#     {'class_id': 1,
#      'x_center': 0.91796875,
#      'y_center': 0.19895833333333332,
#      'width': 0.1578125,
#      'height': 0.20208333333333334},
#     {'class_id': 1,
#      'x_center': 0.76015625,
#      'y_center': 0.07916666666666666,
#      'width': 0.1609375,
#      'height': 0.15416666666666667},
#     {'class_id': 1,
#      'x_center': 0.72890625,
#      'y_center': 0.8520833333333333,
#      'width': 0.1734375,
#      'height': 0.20833333333333334},
#     {'class_id': 1,
#      'x_center': 0.5,
#      'y_center': 0.9260416666666667,
#      'width': 0.16875,
#      'height': 0.14791666666666667},
#     {'class_id': 1,
#      'x_center': 0.10546875,
#      'y_center': 0.9125,
#      'width': 0.2078125,
#      'height': 0.175},
#     {'class_id': 1,
#      'x_center': 0.08046875,
#      'y_center': 0.678125,
#      'width': 0.1578125,
#      'height': 0.22291666666666668},
#     {'class_id': 1,
#      'x_center': 0.17734375,
#      'y_center': 0.240625,
#      'width': 0.1609375,
#      'height': 0.22291666666666668},
#     {'class_id': 1,
#      'x_center': 0.46796875,
#      'y_center': 0.5302083333333333,
#      'width': 0.1609375,
#      'height': 0.22291666666666668},
#     {'class_id': 1,
#      'x_center': 0.23046875,
#      'y_center': 0.7197916666666667,
#      'width': 0.1765625,
#      'height': 0.18958333333333333},
#     {'class_id': 1,
#      'x_center': 0.940625,
#      'y_center': 0.3958333333333333,
#      'width': 0.11875,
#      'height': 0.20833333333333334},
#     {'class_id': 2,
#      'x_center': 0.490625,
#      'y_center': 0.815625,
#      'width': 0.071875,
#      'height': 0.07708333333333334},
#     {'class_id': 1,
#      'x_center': 0.66953125,
#      'y_center': 0.525,
#      'width': 0.1734375,
#      'height': 0.20833333333333334}]},
#   {'filepath': 'BloodImage_00016.jpg',
#    'width': 640,
#    'height': 480,
#    'bboxes': [{'class_id': 0,
#      'x_center': 0.375,
#      'y_center': 0.41354166666666664,
#      'width': 0.278125,
#      'height': 0.33541666666666664},
#     {'class_id': 1,
#      'x_center': 0.28359375,
#      'y_center': 0.7947916666666667,
#      'width': 0.1890625,
#      'height': 0.24375},
#     {'class_id': 1,
#      'x_center': 0.5796875,
#      'y_center': 0.365625,
#      'width': 0.146875,
#      'height': 0.2520833333333333},
#     {'class_id': 1,
#      'x_center': 0.775,
#      'y_center': 0.803125,
#      'width': 0.14375,
#      'height': 0.23541666666666666},
#     {'class_id': 1,
#      'x_center': 0.7390625,
#      'y_center': 0.8760416666666667,
#      'width': 0.14375,
#      'height': 0.23541666666666666},
#     {'class_id': 1,
#      'x_center': 0.45,
#      'y_center': 0.8145833333333333,
#      'width': 0.18125,
#      'height': 0.24166666666666667},
#     {'class_id': 1,
#      'x_center': 0.77890625,
#      'y_center': 0.26979166666666665,
#      'width': 0.1578125,
#      'height': 0.16041666666666668},
#     {'class_id': 1,
#      'x_center': 0.9453125,
#      'y_center': 0.721875,
#      'width': 0.109375,
#      'height': 0.23541666666666666},
#     {'class_id': 1,
#      'x_center': 0.90625,
#      'y_center': 0.253125,
#      'width': 0.178125,
#      'height': 0.21875},
#     {'class_id': 1,
#      'x_center': 0.61328125,
#      'y_center': 0.5791666666666667,
#      'width': 0.1828125,
#      'height': 0.24583333333333332},
#     {'class_id': 1,
#      'x_center': 0.79296875,
#      'y_center': 0.5958333333333333,
#      'width': 0.1828125,
#      'height': 0.24583333333333332},
#     {'class_id': 1,
#      'x_center': 0.1765625,
#      'y_center': 0.44895833333333335,
#      'width': 0.146875,
#      'height': 0.2520833333333333},
#     {'class_id': 2,
#      'x_center': 0.1765625,
#      'y_center': 0.7208333333333333,
#      'width': 0.05,
#      'height': 0.07916666666666666}]},
#   {'filepath': 'BloodImage_00017.jpg',
#    'width': 640,
#    'height': 480,
#    'bboxes': [{'class_id': 0,
#      'x_center': 0.3625,
#      'y_center': 0.63125,
#      'width': 0.325,
#      'height': 0.36666666666666664},
#     {'class_id': 1,
#      'x_center': 0.71875,
#      'y_center': 0.4666666666666667,
#      'width': 0.16875,
#      'height': 0.2},
#     {'class_id': 1,
#      'x_center': 0.7109375,
#      'y_center': 0.26458333333333334,
#      'width': 0.171875,
#      'height': 0.225},
#     {'class_id': 1,
#      'x_center': 0.4015625,
#      'y_center': 0.28541666666666665,
#      'width': 0.13125,
#      'height': 0.20833333333333334},
#     {'class_id': 1,
#      'x_center': 0.7671875,
#      'y_center': 0.73125,
#      'width': 0.175,
#      'height': 0.20416666666666666},
#     {'class_id': 1,
#      'x_center': 0.75,
#      'y_center': 0.8395833333333333,
#      'width': 0.175,
#      'height': 0.20416666666666666},
#     {'class_id': 1,
#      'x_center': 0.2859375,
#      'y_center': 0.8875,
#      'width': 0.1625,
#      'height': 0.18333333333333332},
#     {'class_id': 1,
#      'x_center': 0.8328125,
#      'y_center': 0.43333333333333335,
#      'width': 0.1625,
#      'height': 0.18333333333333332},
#     {'class_id': 1,
#      'x_center': 0.08359375,
#      'y_center': 0.8010416666666667,
#      'width': 0.1515625,
#      'height': 0.20625},
#     {'class_id': 1,
#      'x_center': 0.0421875,
#      'y_center': 0.31875,
#      'width': 0.08125,
#      'height': 0.21666666666666667},
#     {'class_id': 1,
#      'x_center': 0.43828125,
#      'y_center': 0.8895833333333333,
#      'width': 0.1859375,
#      'height': 0.15416666666666667},
#     {'class_id': 1,
#      'x_center': 0.325,
#      'y_center': 0.08854166666666667,
#      'width': 0.1625,
#      'height': 0.17291666666666666},
#     {'class_id': 1,
#      'x_center': 0.515625,
#      'y_center': 0.18958333333333333,
#      'width': 0.159375,
#      'height': 0.225},
#     {'class_id': 1,
#      'x_center': 0.89765625,
#      'y_center': 0.09166666666666666,
#      'width': 0.1453125,
#      'height': 0.17916666666666667},
#     {'class_id': 1,
#      'x_center': 0.83515625,
#      'y_center': 0.11354166666666667,
#      'width': 0.1453125,
#      'height': 0.18125},
#     {'class_id': 1,
#      'x_center': 0.0859375,
#      'y_center': 0.6229166666666667,
#      'width': 0.159375,
#      'height': 0.225},
#     {'class_id': 1,
#      'x_center': 0.5828125,
#      'y_center': 0.8104166666666667,
#      'width': 0.159375,
#      'height': 0.225},
#     {'class_id': 2,
#      'x_center': 0.62578125,
#      'y_center': 0.13125,
#      'width': 0.0578125,
#      'height': 0.06666666666666667}]},
#   {'filepath': 'BloodImage_00018.jpg',
#    'width': 640,
#    'height': 480,
#    'bboxes': [{'class_id': 0,
#      'x_center': 0.61171875,
#      'y_center': 0.17395833333333333,
#      'width': 0.2796875,
#      'height': 0.34375},
#     {'class_id': 1,
#      'x_center': 0.3703125,
#      'y_center': 0.309375,
#      'width': 0.21875,
#      'height': 0.20208333333333334},
#     {'class_id': 1,
#      'x_center': 0.41328125,
#      'y_center': 0.06770833333333333,
#      'width': 0.1703125,
#      'height': 0.13125},
#     {'class_id': 1,
#      'x_center': 0.9375,
#      'y_center': 0.2677083333333333,
#      'width': 0.121875,
#      'height': 0.22708333333333333},
#     {'class_id': 1,
#      'x_center': 0.28125,
#      'y_center': 0.15729166666666666,
#      'width': 0.15625,
#      'height': 0.20625},
#     {'class_id': 1,
#      'x_center': 0.1859375,
#      'y_center': 0.48541666666666666,
#      'width': 0.140625,
#      'height': 0.18333333333333332},
#     {'class_id': 1,
#      'x_center': 0.5453125,
#      'y_center': 0.42916666666666664,
#      'width': 0.140625,
#      'height': 0.18333333333333332},
#     {'class_id': 1,
#      'x_center': 0.6375,
#      'y_center': 0.43125,
#      'width': 0.140625,
#      'height': 0.18333333333333332},
#     {'class_id': 1,
#      'x_center': 0.7109375,
#      'y_center': 0.4083333333333333,
#      'width': 0.140625,
#      'height': 0.18333333333333332},
#     {'class_id': 1,
#      'x_center': 0.7421875,
#      'y_center': 0.3645833333333333,
#      'width': 0.140625,
#      'height': 0.18333333333333332},
#     {'class_id': 1,
#      'x_center': 0.825,
#      'y_center': 0.31875,
#      'width': 0.140625,
#      'height': 0.18333333333333332},
#     {'class_id': 1,
#      'x_center': 0.915625,
#      'y_center': 0.6666666666666666,
#      'width': 0.140625,
#      'height': 0.18333333333333332},
#     {'class_id': 1,
#      'x_center': 0.946875,
#      'y_center': 0.4875,
#      'width': 0.10625,
#      'height': 0.22083333333333333},
#     {'class_id': 1,
#      'x_center': 0.51640625,
#      'y_center': 0.9416666666666667,
#      'width': 0.1390625,
#      'height': 0.11666666666666667},
#     {'class_id': 1,
#      'x_center': 0.56953125,
#      'y_center': 0.5885416666666666,
#      'width': 0.1765625,
#      'height': 0.17708333333333334},
#     {'class_id': 1,
#      'x_center': 0.36484375,
#      'y_center': 0.8,
#      'width': 0.1390625,
#      'height': 0.1625},
#     {'class_id': 1,
#      'x_center': 0.0703125,
# ...
#      'width': 0.1609375,
#      'height': 0.20416666666666666},
#     {'class_id': 1,
#      'x_center': 0.09765625,
#      'y_center': 0.66875,
#      'width': 0.1609375,
#      'height': 0.20416666666666666},
#     {'class_id': 1,
#      'x_center': 0.20390625,
#      'y_center': 0.8510416666666667,
#      'width': 0.1640625,
#      'height': 0.16875},
#     {'class_id': 1,
#      'x_center': 0.84375,
#      'y_center': 0.13125,
#      'width': 0.15625,
#      'height': 0.22083333333333333},
#     {'class_id': 1,
#      'x_center': 0.934375,
#      'y_center': 0.33645833333333336,
#      'width': 0.13125,
#      'height': 0.14791666666666667},
#     {'class_id': 0,
#      'x_center': 0.27890625,
#      'y_center': 0.5552083333333333,
#      'width': 0.3390625,
#      'height': 0.42291666666666666},
#     {'class_id': 2,
#      'x_center': 0.625,
#      'y_center': 0.609375,
#      'width': 0.096875,
#      'height': 0.13541666666666666},
#     {'class_id': 2,
#      'x_center': 0.92109375,
#      'y_center': 0.046875,
#      'width': 0.0796875,
#      'height': 0.08958333333333333}]},
#   {'filepath': 'BloodImage_00404.jpg',
#    'width': 640,
#    'height': 480,
#    'bboxes': [{'class_id': 1,
#      'x_center': 0.72421875,
#      'y_center': 0.4979166666666667,
#      'width': 0.2046875,
#      'height': 0.17916666666666667},
#     {'class_id': 1,
#      'x_center': 0.74453125,
#      'y_center': 0.23020833333333332,
#      'width': 0.1890625,
#      'height': 0.23958333333333334},
#     {'class_id': 1,
#      'x_center': 0.92421875,
#      'y_center': 0.24895833333333334,
#      'width': 0.1515625,
#      'height': 0.23958333333333334},
#     {'class_id': 1,
#      'x_center': 0.5171875,
#      'y_center': 0.19791666666666666,
#      'width': 0.1625,
#      'height': 0.21666666666666667},
#     {'class_id': 1,
#      'x_center': 0.375,
#      'y_center': 0.8354166666666667,
#      'width': 0.1625,
#      'height': 0.19166666666666668},
#     {'class_id': 1,
#      'x_center': 0.503125,
#      'y_center': 0.8145833333333333,
#      'width': 0.11875,
#      'height': 0.17916666666666667},
#     {'class_id': 1,
#      'x_center': 0.60859375,
#      'y_center': 0.7427083333333333,
#      'width': 0.1578125,
#      'height': 0.21041666666666667},
#     {'class_id': 1,
#      'x_center': 0.71796875,
#      'y_center': 0.809375,
#      'width': 0.1953125,
#      'height': 0.18541666666666667},
#     {'class_id': 1,
#      'x_center': 0.77578125,
#      'y_center': 0.709375,
#      'width': 0.1953125,
#      'height': 0.18541666666666667},
#     {'class_id': 1,
#      'x_center': 0.0734375,
#      'y_center': 0.8666666666666667,
#      'width': 0.14375,
#      'height': 0.21666666666666667},
#     {'class_id': 1,
#      'x_center': 0.203125,
#      'y_center': 0.2375,
#      'width': 0.1875,
#      'height': 0.17916666666666667},
#     {'class_id': 1,
#      'x_center': 0.38359375,
#      'y_center': 0.07395833333333333,
#      'width': 0.1890625,
#      'height': 0.14375},
#     {'class_id': 1,
#      'x_center': 0.9484375,
#      'y_center': 0.4864583333333333,
#      'width': 0.103125,
#      'height': 0.22708333333333333},
#     {'class_id': 0,
#      'x_center': 0.3734375,
#      'y_center': 0.5239583333333333,
#      'width': 0.3875,
#      'height': 0.4895833333333333},
#     {'class_id': 2,
#      'x_center': 0.07421875,
#      'y_center': 0.64375,
#      'width': 0.0734375,
#      'height': 0.075}]},
#   {'filepath': 'BloodImage_00405.jpg',
#    'width': 640,
#    'height': 480,
#    'bboxes': [{'class_id': 1,
#      'x_center': 0.16796875,
#      'y_center': 0.7479166666666667,
#      'width': 0.1703125,
#      'height': 0.22083333333333333},
#     {'class_id': 1,
#      'x_center': 0.05390625,
#      'y_center': 0.546875,
#      'width': 0.1046875,
#      'height': 0.24791666666666667},
#     {'class_id': 1,
#      'x_center': 0.33828125,
#      'y_center': 0.34791666666666665,
#      'width': 0.1703125,
#      'height': 0.22083333333333333},
#     {'class_id': 1,
#      'x_center': 0.25859375,
#      'y_center': 0.290625,
#      'width': 0.1734375,
#      'height': 0.23958333333333334},
#     {'class_id': 1,
#      'x_center': 0.309375,
#      'y_center': 0.09375,
#      'width': 0.146875,
#      'height': 0.18333333333333332},
#     {'class_id': 1,
#      'x_center': 0.453125,
#      'y_center': 0.09375,
#      'width': 0.146875,
#      'height': 0.18333333333333332},
#     {'class_id': 1,
#      'x_center': 0.8765625,
#      'y_center': 0.5302083333333333,
#      'width': 0.1625,
#      'height': 0.20208333333333334},
#     {'class_id': 1,
#      'x_center': 0.8296875,
#      'y_center': 0.31979166666666664,
#      'width': 0.1625,
#      'height': 0.20208333333333334},
#     {'class_id': 1,
#      'x_center': 0.66875,
#      'y_center': 0.396875,
#      'width': 0.1625,
#      'height': 0.20208333333333334},
#     {'class_id': 1,
#      'x_center': 0.4671875,
#      'y_center': 0.596875,
#      'width': 0.190625,
#      'height': 0.21458333333333332},
#     {'class_id': 1,
#      'x_center': 0.36484375,
#      'y_center': 0.5489583333333333,
#      'width': 0.1796875,
#      'height': 0.21458333333333332},
#     {'class_id': 1,
#      'x_center': 0.3234375,
#      'y_center': 0.8010416666666667,
#      'width': 0.153125,
#      'height': 0.26875},
#     {'class_id': 1,
#      'x_center': 0.53515625,
#      'y_center': 0.8239583333333333,
#      'width': 0.1109375,
#      'height': 0.24791666666666667},
#     {'class_id': 1,
#      'x_center': 0.59921875,
#      'y_center': 0.16041666666666668,
#      'width': 0.2109375,
#      'height': 0.31666666666666665},
#     {'class_id': 0,
#      'x_center': 0.703125,
#      'y_center': 0.7270833333333333,
#      'width': 0.35,
#      'height': 0.42083333333333334}]},
#   {'filepath': 'BloodImage_00407.jpg',
#    'width': 640,
#    'height': 480,
#    'bboxes': [{'class_id': 1,
#      'x_center': 0.1328125,
#      'y_center': 0.45,
#      'width': 0.171875,
#      'height': 0.2},
#     {'class_id': 1,
#      'x_center': 0.09453125,
#      'y_center': 0.175,
#      'width': 0.1515625,
#      'height': 0.20416666666666666},
#     {'class_id': 1,
#      'x_center': 0.1265625,
#      'y_center': 0.8375,
#      'width': 0.175,
#      'height': 0.20833333333333334},
#     {'class_id': 1,
#      'x_center': 0.2578125,
#      'y_center': 0.7666666666666667,
#      'width': 0.175,
#      'height': 0.20833333333333334},
#     {'class_id': 1,
#      'x_center': 0.33671875,
#      'y_center': 0.6260416666666667,
#      'width': 0.1796875,
#      'height': 0.2520833333333333},
#     {'class_id': 1,
#      'x_center': 0.46328125,
#      'y_center': 0.8197916666666667,
#      'width': 0.1515625,
#      'height': 0.19791666666666666},
#     {'class_id': 1,
#      'x_center': 0.62734375,
#      'y_center': 0.7020833333333333,
#      'width': 0.1609375,
#      'height': 0.1875},
#     {'class_id': 1,
#      'x_center': 0.609375,
#      'y_center': 0.23541666666666666,
#      'width': 0.190625,
#      'height': 0.22916666666666666},
#     {'class_id': 1,
#      'x_center': 0.3671875,
#      'y_center': 0.10625,
#      'width': 0.203125,
#      'height': 0.20833333333333334},
#     {'class_id': 1,
#      'x_center': 0.34765625,
#      'y_center': 0.3260416666666667,
#      'width': 0.1703125,
#      'height': 0.19375},
#     {'class_id': 1,
#      'x_center': 0.3875,
#      'y_center': 0.39791666666666664,
#      'width': 0.140625,
#      'height': 0.1625},
#     {'class_id': 1,
#      'x_center': 0.7234375,
#      'y_center': 0.08020833333333334,
#      'width': 0.234375,
#      'height': 0.15625},
#     {'class_id': 1,
#      'x_center': 0.90703125,
#      'y_center': 0.54375,
#      'width': 0.1765625,
#      'height': 0.16666666666666666},
#     {'class_id': 1,
#      'x_center': 0.79921875,
#      'y_center': 0.340625,
#      'width': 0.1296875,
#      'height': 0.17291666666666666},
#     {'class_id': 1,
#      'x_center': 0.87265625,
#      'y_center': 0.3072916666666667,
#      'width': 0.1484375,
#      'height': 0.22291666666666668},
#     {'class_id': 0,
#      'x_center': 0.86875,
#      'y_center': 0.7958333333333333,
#      'width': 0.2625,
#      'height': 0.38333333333333336},
#     {'class_id': 2,
#      'x_center': 0.69921875,
#      'y_center': 0.5552083333333333,
#      'width': 0.1078125,
#      'height': 0.15208333333333332},
#     {'class_id': 2,
#      'x_center': 0.14140625,
#      'y_center': 0.28125,
#      'width': 0.0703125,
#      'height': 0.09166666666666666},
#     {'class_id': 2,
#      'x_center': 0.215625,
#      'y_center': 0.09270833333333334,
#      'width': 0.08125,
#      'height': 0.08125}]},
#   {'filepath': 'BloodImage_00408.jpg',
#    'width': 640,
#    'height': 480,
#    'bboxes': [{'class_id': 1,
#      'x_center': 0.15859375,
#      'y_center': 0.7229166666666667,
#      'width': 0.1171875,
#      'height': 0.2833333333333333},
#     {'class_id': 1,
#      'x_center': 0.2734375,
#      'y_center': 0.353125,
#      'width': 0.178125,
#      'height': 0.20625},
#     {'class_id': 1,
#      'x_center': 0.07265625,
#      'y_center': 0.4739583333333333,
#      'width': 0.1421875,
#      'height': 0.20625},
#     {'class_id': 1,
#      'x_center': 0.41328125,
#      'y_center': 0.7375,
#      'width': 0.1609375,
#      'height': 0.20833333333333334},
#     {'class_id': 1,
#      'x_center': 0.4125,
#      'y_center': 0.9072916666666667,
#      'width': 0.153125,
#      'height': 0.18541666666666667},
#     {'class_id': 1,
#      'x_center': 0.78984375,
#      'y_center': 0.6,
#      'width': 0.1609375,
#      'height': 0.19583333333333333},
#     {'class_id': 1,
#      'x_center': 0.56953125,
#      'y_center': 0.46979166666666666,
#      'width': 0.1765625,
#      'height': 0.19791666666666666},
#     {'class_id': 1,
#      'x_center': 0.528125,
#      'y_center': 0.21458333333333332,
#      'width': 0.16875,
#      'height': 0.23333333333333334},
#     {'class_id': 1,
#      'x_center': 0.815625,
#      'y_center': 0.071875,
#      'width': 0.1625,
#      'height': 0.13958333333333334},
#     {'class_id': 1,
#      'x_center': 0.6875,
#      'y_center': 0.190625,
#      'width': 0.153125,
#      'height': 0.19791666666666666},
#     {'class_id': 1,
#      'x_center': 0.67734375,
#      'y_center': 0.40520833333333334,
#      'width': 0.1453125,
#      'height': 0.24375},
#     {'class_id': 1,
#      'x_center': 0.9125,
#      'y_center': 0.6604166666666667,
#      'width': 0.13125,
#      'height': 0.19166666666666668},
#     {'class_id': 1,
#      'x_center': 0.0890625,
#      'y_center': 0.16979166666666667,
#      'width': 0.15,
#      'height': 0.22291666666666668},
#     {'class_id': 1,
#      'x_center': 0.2375,
#      'y_center': 0.1,
#      'width': 0.153125,
#      'height': 0.19583333333333333},
#     {'class_id': 1,
#      'x_center': 0.37734375,
#      'y_center': 0.08541666666666667,
#      'width': 0.1359375,
#      'height': 0.16666666666666666},
#     {'class_id': 2,
#      'x_center': 0.0171875,
#      'y_center': 0.621875,
#      'width': 0.03125,
#      'height': 0.07291666666666667},
#     {'class_id': 2,
#      'x_center': 0.63046875,
#      'y_center': 0.5604166666666667,
#      'width': 0.0640625,
#      'height': 0.0625},
#     {'class_id': 0,
#      'x_center': 0.68671875,
#      'y_center': 0.8322916666666667,
#      'width': 0.4046875,
#      'height': 0.33541666666666664}]},
#   {'filepath': 'BloodImage_00409.jpg',
#    'width': 640,
#    'height': 480,
#    'bboxes': [{'class_id': 1,
#      'x_center': 0.88203125,
#      'y_center': 0.45416666666666666,
#      'width': 0.1453125,
#      'height': 0.20833333333333334},
#     {'class_id': 1,
#      'x_center': 0.76328125,
#      'y_center': 0.296875,
#      'width': 0.1953125,
#      'height': 0.23125},
#     {'class_id': 1,
#      'x_center': 0.86953125,
#      'y_center': 0.7385416666666667,
#      'width': 0.1703125,
#      'height': 0.23541666666666666},
#     {'class_id': 1,
#      'x_center': 0.48515625,
#      'y_center': 0.6270833333333333,
#      'width': 0.1890625,
#      'height': 0.23333333333333334},
#     {'class_id': 1,
#      'x_center': 0.178125,
#      'y_center': 0.33229166666666665,
#      'width': 0.175,
#      'height': 0.23125},
#     {'class_id': 1,
#      'x_center': 0.6890625,
#      'y_center': 0.6520833333333333,
#      'width': 0.196875,
#      'height': 0.22916666666666666},
#     {'class_id': 1,
#      'x_center': 0.428125,
#      'y_center': 0.3572916666666667,
#      'width': 0.14375,
#      'height': 0.18958333333333333},
#     {'class_id': 1,
#      'x_center': 0.3359375,
#      'y_center': 0.259375,
#      'width': 0.14375,
#      'height': 0.18958333333333333},
#     {'class_id': 1,
#      'x_center': 0.07421875,
#      'y_center': 0.0875,
#      'width': 0.1421875,
#      'height': 0.17083333333333334},
#     {'class_id': 1,
#      'x_center': 0.10703125,
#      'y_center': 0.5645833333333333,
#      'width': 0.1640625,
#      'height': 0.175},
#     {'class_id': 1,
#      'x_center': 0.0953125,
#      'y_center': 0.65625,
#      'width': 0.16875,
#      'height': 0.21666666666666667},
#     {'class_id': 1,
#      'x_center': 0.62890625,
#      'y_center': 0.43020833333333336,
#      'width': 0.1671875,
#      'height': 0.33125},
#     {'class_id': 1,
#      'x_center': 0.78203125,
#      'y_center': 0.08125,
#      'width': 0.1953125,
#      'height': 0.15833333333333333},
#     {'class_id': 1,
#      'x_center': 0.41953125,
#      'y_center': 0.23020833333333332,
#      'width': 0.1296875,
#      'height': 0.16458333333333333},
#     {'class_id': 2,
#      'x_center': 0.67890625,
#      'y_center': 0.8635416666666667,
#      'width': 0.0671875,
#      'height': 0.07708333333333334},
#     {'class_id': 2,
#      'x_center': 0.55546875,
#      'y_center': 0.47708333333333336,
#      'width': 0.0671875,
#      'height': 0.07916666666666666},
#     {'class_id': 2,
#      'x_center': 0.30703125,
#      'y_center': 0.40208333333333335,
#      'width': 0.0515625,
#      'height': 0.1},
#     {'class_id': 2,
#      'x_center': 0.15625,
#      'y_center': 0.06875,
#      'width': 0.06875,
#      'height': 0.075},
#     {'class_id': 0,
#      'x_center': 0.3,
#      'y_center': 0.8052083333333333,
#      'width': 0.35625,
#      'height': 0.38958333333333334}]},
#   {'filepath': 'BloodImage_00410.jpg',
#    'width': 640,
#    'height': 480,
#    'bboxes': [{'class_id': 1,
#      'x_center': 0.44609375,
#      'y_center': 0.8541666666666666,
#      'width': 0.1640625,
#      'height': 0.175},
#     {'class_id': 1,
#      'x_center': 0.6265625,
#      'y_center': 0.896875,
#      'width': 0.171875,
#      'height': 0.18958333333333333},
#     {'class_id': 1,
#      'x_center': 0.4625,
#      'y_center': 0.246875,
#      'width': 0.171875,
#      'height': 0.18958333333333333},
#     {'class_id': 1,
#      'x_center': 0.48125,
#      'y_center': 0.08958333333333333,
#      'width': 0.18125,
#      'height': 0.175},
#     {'class_id': 1,
#      'x_center': 0.259375,
#      'y_center': 0.7739583333333333,
#      'width': 0.1875,
#      'height': 0.23541666666666666},
#     {'class_id': 1,
#      'x_center': 0.53359375,
#      'y_center': 0.42083333333333334,
#      'width': 0.1640625,
#      'height': 0.175},
#     {'class_id': 1,
#      'x_center': 0.62890625,
#      'y_center': 0.3145833333333333,
#      'width': 0.1640625,
#      'height': 0.175},
#     {'class_id': 1,
#      'x_center': 0.24453125,
#      'y_center': 0.12916666666666668,
#      'width': 0.1640625,
#      'height': 0.175},
#     {'class_id': 1,
#      'x_center': 0.08515625,
#      'y_center': 0.565625,
#      'width': 0.1671875,
#      'height': 0.21041666666666667},
#     {'class_id': 1,
#      'x_center': 0.95390625,
#      'y_center': 0.8947916666666667,
#      'width': 0.0890625,
#      'height': 0.21041666666666667},
#     {'class_id': 1,
#      'x_center': 0.79609375,
#      'y_center': 0.8625,
#      'width': 0.1640625,
#      'height': 0.175},
#     {'class_id': 1,
#      'x_center': 0.93984375,
#      'y_center': 0.13854166666666667,
#      'width': 0.1203125,
#      'height': 0.19375},
#     {'class_id': 1,
#      'x_center': 0.55,
#      'y_center': 0.6760416666666667,
#      'width': 0.15,
#      'height': 0.2604166666666667},
#     {'class_id': 2,
#      'x_center': 0.4140625,
#      'y_center': 0.6208333333333333,
#      'width': 0.08125,
#      'height': 0.09583333333333334},
#     {'class_id': 2,
#      'x_center': 0.2421875,
#      'y_center': 0.6041666666666666,
#      'width': 0.10625,
#      'height': 0.125},
#     {'class_id': 2,
#      'x_center': 0.12578125,
#      'y_center': 0.29791666666666666,
#      'width': 0.0734375,
#      'height': 0.1},
#     {'class_id': 2,
#      'x_center': 0.0234375,
#      'y_center': 0.6385416666666667,
#      'width': 0.04375,
#      'height': 0.08541666666666667},
#     {'class_id': 0,
#      'x_center': 0.7640625,
#      'y_center': 0.5833333333333334,
#      'width': 0.38125,
#      'height': 0.475}]}]}
